# %% [markdown]
#  # Połączenie z bazą danych przy pomocy sqlAlchemy

# %%
from sqlalchemy import create_engine

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)
connection_sqlalchemy = db.connect()

# %% [markdown]
# # 1. Ile kategorii filmów mamy w wypożyczalni?

# %%
df = pd.read_sql('select * from category', con=connection_sqlalchemy)
len(df.index)
# Out:
# 16

# %% [markdown]
# # 2. Wyświetl listę kategorii w kolejności alfabetycznej.

# %%
df
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27

# %% [markdown]
# # 3. Znajdź najstarszy i najmłodszy film do wypożyczenia.

# %%
df = pd.read_sql('select * from film order by release_year asc fetch first row only', con=connection_sqlalchemy)
df
# Out:
#    film_id            title  \
# 0      133  Chamber Italian
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
#
#               last_update special_features  \
# 0 2013-05-26 14:50:58.951       [Trailers]
#
#                                             fulltext
# 0  'chamber':1 'fate':4 'husband':11 'italian':2 ...

# %%
df = pd.read_sql('select * from film order by release_year desc fetch first row only', con=connection_sqlalchemy)
df
# Out:
#    film_id            title  \
# 0      133  Chamber Italian
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
#
#               last_update special_features  \
# 0 2013-05-26 14:50:58.951       [Trailers]
#
#                                             fulltext
# 0  'chamber':1 'fate':4 'husband':11 'italian':2 ...

# %% [markdown]
# # 4. Ile wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?

# %%
df = pd.read_sql("select * from rental where rental_date between '2005-07-01 00:00:00' and '2005-08-01 23:59:59'", con=connection_sqlalchemy)
len(df.index)
# Out:
# 7380

# %% [markdown]
# # 5. Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?

# %%
df = pd.read_sql("select * from rental where rental_date between '2010-01-01 00:00:00' and '2011-02-01 23:59:59'", con=connection_sqlalchemy)
len(df.index)
# Out:
# 0

# %% [markdown]
# # 6. Znajdź największą płatność wypożyczenia.

# %%
df = pd.read_sql('select * from payment order by amount desc limit 1', con=connection_sqlalchemy)
df
# Out:
#    payment_id  customer_id  staff_id  rental_id  amount  \
# 0       20403          362         1      14759   11.99
#
#                 payment_date
# 0 2007-03-21 21:57:24.996577

# %% [markdown]
# # 7. Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.

# %%
df = pd.read_sql("select distinct * from customer_list where country in ('Poland', 'Nigeria', 'Bangladesh')", con=connection_sqlalchemy)
df
# Out:
#      id              name                         address zip code  \
# 0    18      Carol Garcia                320 Brest Avenue    43331
# 1    21    Michelle Clark  262 A Corua (La Corua) Parkway    34418
# 2    80      Marilyn Ross                1888 Kabul Drive    20936
# 3   103   Gladys Hamilton                 1177 Jelets Way     3305
# 4   128   Marjorie Tucker        1050 Garden Grove Avenue     4999
# 5   156   Bertha Ferguson               1367 Yantai Manor    21294
# 6   198      Elsie Kelley                 955 Bamenda Way     1545
# 7   232    Constance Reid               885 Yingkou Manor    31390
# 8   250         Jo Fowler            786 Stara Zagora Way    98332
# 9   270       Leah Curtis                  906 Goinia Way    83565
# 10  277      Olga Jimenez                556 Baybay Manor    55802
# 11  280    Tracey Barrett  1006 Santa Brbara dOeste Manor    36229
# 12  284     Sonia Gregory              1279 Udine Parkway    75860
# ...

# %% [markdown]
# # 8. Gdzie mieszkają członkowie personelu?

# %%
df = pd.read_sql('select distinct country from staff_list', con=connection_sqlalchemy)
df
# Out:
#      country
# 0  Australia
# 1     Canada

# %% [markdown]
# # 9. Ilu pracowników mieszka w Argentynie lub Hiszpanii?

# %%
df = pd.read_sql("select distinct * from staff_list where country in ('Argentina', 'Spain')", con=connection_sqlalchemy)
len(df)
# Out:
# 0

# %% [markdown]
# # 10. Jakie kategorie filmów zostały wypożyczone przez klientów?

# %%
df = pd.read_sql("select distinct category from sales_by_film_category where total_sales > 0", con=connection_sqlalchemy)
df
# Out:
#        category
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %% [markdown]
# # 11. Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.

# %%
df = pd.read_sql("select distinct category from film_list where FID in (select film_id from inventory where inventory_id in (select inventory_id from rental where customer_id in (select id from customer_list where country = 'United States')))", con=connection_sqlalchemy)
df
# Out:
#        category
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8         Drama
# 9        Horror
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children

# %% [markdown]
# # 12. Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley

# %%
df = pd.read_sql("select distinct title from film_list where actors like '%%Olympia Pfeiffer%%' or actors like '%%Julia Zellweger%%' or actors like '%%Ellen Presley%%'", con=connection_sqlalchemy)
df
# Out:
#                    title
# 0            Badman Dawn
# 1        Bilko Anonymous
# 2   Breakfast Goldfinger
# 3      Caribbean Liberty
# 4       Casper Dragonfly
# ..                   ...
# 64             Turn Star
# 65            Wait Cider
# 66          Women Dorado
# 67             Won Dares
# 68         Wyoming Storm
#
# [69 rows x 1 columns]
