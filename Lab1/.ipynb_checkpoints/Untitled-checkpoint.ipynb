# %% [markdown]
# Wojciech Wiszniewski

# %% [markdown]
# Cel ćwiczenia

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-1,1,100)
x1 = np.linspace(-6, 6, 100)
x2 = np.linspace(0, 5, 100)

# %%
y = x**2 + 5
fig = plt.figure()
plt.plot(x,y, label = "y = x^2 + 5")
plt.title("Wykres funkcji x^2 + 5")
plt.xlabel("Argument x")
plt.ylabel("Wartość funkcji")
plt.legend()
plt.show()

# %%
y = x1**2 + 5
fig = plt.figure()
plt.plot(x1,y,label = "y = x^2 + 5")
plt.title("Wykres funkcji x^2 + 5")
plt.xlabel("Argument x")
plt.ylabel("Wartość funkcji")
plt.legend()
plt.show()

# %%
y = x2**2 + 5
fig = plt.figure()
plt.plot(x2,y, label = "y = x^2 + 5")
plt.title("Wykres funkcji x^2 + 5")
plt.xlabel("Argument x")
plt.ylabel("Wartość funkcji")
plt.legend()
plt.show()
